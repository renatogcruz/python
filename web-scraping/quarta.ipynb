# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve, Request
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

# Obtendo o HTML

response = urlopen('https://www.euamomomi.com.br/blusa-infantil-feminina')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')

# total de página
pages = 3

# iterando todas as páginas do site
for i in range(pages):
    # Obtendo html
    response = urlopen('https://www.euamomomi.com.br/blusa-infantil-feminina?p=' + str(i + 1))
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')

    # Obtendo as TAGs de interesse
    anuncios = soup.find('div', {"id": "lista-produtos-area"}).findAll('li')

    # Coletando as informações dos cards
    for anuncio in anuncios:      
   
        ## OBTENDO HIPERLINK        
        if anuncio.find('a') != None:
            link = 'https:' + anuncio.find('a').get('href')
            
            # obtendoHtml do hiperlink (link)
            response = urlopen(link)
            html = response.read().decode('utf-8')
            soup = BeautifulSoup(html, 'html.parser')
            
            # Abrindo dicionário
            card = {}
            
            # Obtendo as TAGs de interesse
            #dados = soup.find('div', {'class': 'lista-dados-produto'})
            if  soup.find('div', {'class': 'container container-product'}) != None:
                dados = soup.find('div', {'class': 'container container-product'})

                # nome do produto
                if dados.find('h1', {'itemprop': 'name'}) != None:
                    card['nome do produto'] = dados.find('h1', {'itemprop': 'name'}).get_text()
                  
                # Descrição do produto
                if  dados.find('div', {'class': 'content'}) != None:
                    card['descrição do produto'] = dados.find('div', {'class': 'content'}).get_text()
                
                #  composição            
                if dados.find('div', {'class': 'composicao'}).find('div', {'class': 'content'}) != None:
                    card['composição'] = dados.find('div', {'class': 'composicao'}).find('div', {'class': 'content'}).get_text()

                # tamanhos (lista com tamanhos disponíveis)
                if dados.find('div', {'id': 'variacao-area-id-2'}) != None:
                    tamanhos = dados.find('div', {'id': 'variacao-area-id-2'}).findAll('li')

                    t = []

                    for tamanho in tamanhos:
                        num = tamanho.get_text().replace(' ', '')
                        t.append(num)
                    card['tamanhos'] = t
                 
                # fotos (lista com as urls das imagens)
                if dados.findAll('li', {'class': 'clearfix'}) != None:
                    todas_imagem = dados.findAll('li', {'class': 'clearfix'})
                    
                    x = []
                    
                    for i in todas_imagem:
                        im = i.get('data-img-full')
                        x.append(im)
                    card['fotos'] = x

                # Adicionando resultado à lista cards
                cards.append(card)


# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_excel('./dataset.xlsx', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#                                       nome do produto  \
# 0        Colete Jeans com Aplicação em Moletom Rosa
# 1                Blusa Azul Estampa Good Vibes Momi
# 2       Blusa Off White Manga Curta Estampa de Gato
# 3      Blusa Manga Curta com Estampa de Óculos Momi
# 4    Blusa Branca Manga Curta com Estampa de Ursin...
# 5               Blusa Branca com Babados nas Mangas
# 6          Blusa Estampada de Planeta Branca e Rosa
# 7                Blusa Branca com Estampa Fofa Momi
# 8               Regata Branca Arco-Íris com Franjas
# 9          Blusa Estampa Colorida com Detalhes Neon
# 10    Blusa Infantil Menina Canelada Off White Momi
# 11              Blusa Infantil Menina Vermelha Momi
# 35                          96% Algodão, 4% Elastano
# 36           70% Algodão, 27% Poliamida, 3% Elastano
# 37                          96% Algodão, 4% Elastano
# 38                          96% Algodão, 4% Elastano
# 39                          96% Algodão, 4% Elastano
# 40                          96% Algodão, 4% Elastano
# 41                          96% Algodão, 4% Elastano
# 42                          96% Algodão, 4% Elastano
# 43                          96% Algodão, 4% Elastano
# 44                          96% Algodão, 4% Elastano
# 45           70% Algodão, 27% Poliamida, 3% Elastano
#
#                      tamanhos  \
# 0   [4, 6, 8, 10, 12, 14, 16]
# 1   [4, 6, 8, 10, 12, 14, 16]
# 2   [4, 6, 8, 10, 12, 14, 16]
# 3          [1, 2, 3, 4, 6, 8]
# 4          [1, 2, 3, 4, 6, 8]
# 5   [4, 6, 8, 10, 12, 14, 16]
# 6          [1, 2, 3, 4, 6, 8]
# 7   [4, 6, 8, 10, 12, 14, 16]
# 8          [1, 2, 3, 4, 6, 8]
# 9          [1, 2, 3, 4, 6, 8]
# 10      [4, 6, 8, 10, 12, 14]
# 11      [4, 6, 8, 10, 12, 14]
# 12         [1, 2, 3, 4, 6, 8]
# 13         [1, 2, 3, 4, 6, 8]
# 14      [4, 6, 8, 10, 12, 14]
# 15      [4, 6, 8, 10, 12, 14]
# 16      [4, 6, 8, 10, 12, 14]
# 17         [1, 2, 3, 4, 6, 8]
# 18         [1, 2, 3, 4, 6, 8]
# 19   [2, 4, 6, 8, 10, 12, 14]
# 20   [2, 4, 6, 8, 10, 12, 14]
# 21  [4, 6, 8, 10, 12, 14, 16]
# 22   [2, 4, 6, 8, 10, 12, 14]
# 23         [1, 2, 3, 4, 6, 8]
# 24  [4, 6, 8, 10, 12, 14, 16]
# 25         [1, 2, 3, 4, 6, 8]
# 26      [4, 6, 8, 10, 12, 14]
# 27         [1, 2, 3, 4, 6, 8]
# 28         [1, 2, 3, 4, 6, 8]
# 29         [1, 2, 3, 4, 6, 8]
# 30            [1, 2, 3, 4, 6]
# 31            [1, 2, 3, 4, 6]
# 32      [4, 6, 8, 10, 12, 14]
# 33      [4, 6, 8, 10, 12, 14]
# 34      [4, 6, 8, 10, 12, 14]
# 35            [1, 2, 3, 4, 6]
# 36      [4, 6, 8, 10, 12, 14]
# 37            [1, 2, 3, 4, 6]
# 38            [1, 2, 3, 4, 6]
# 39            [1, 2, 3, 4, 6]
# 40   [2, 4, 6, 8, 10, 12, 14]
# 41            [1, 2, 3, 4, 6]
# 42      [4, 6, 8, 10, 12, 14]
# 43      [4, 6, 8, 10, 12, 14]
# 44      [4, 6, 8, 10, 12, 14]
# 45            [1, 2, 3, 4, 6]
#
#                                                 fotos
# 0   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 1   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 2   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 3   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 4   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 5   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 6   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 7   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 8   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 9   [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 10  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 11  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 12  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 13  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 14  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 15  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 16  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 17  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 18  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 19  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 20  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 21  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 22  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 23  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 24  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 25  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 26  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 27  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 28  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 29  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 30  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 31  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 32  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 33  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 34  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 35  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 36  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 37  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 38  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 39  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 40  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 41  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 42  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 43  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 44  [https://texcotton.s3-sa-east-1.amazonaws.com/...
# 45  [https://texcotton.s3-sa-east-1.amazonaws.com/...

# %% [markdown]
# ```python
#         # tamanhos (lista com tamanhos disponíveis)
#         if anuncio.find('div', {'class': 'derivacao-lista'}) != None:
#             tamanhos = anuncio.find('div', {'class': 'derivacao-lista'}).findAll('div', {'class': 'deriva tamanho'})
#
#             x = []
#
#             for tamanho in tamanhos:
#                 num = tamanho.get_text().replace(' ', '')
#                 x.append(num)
#             card['tamanhos'] = x
#
# ```

# %% [markdown]
#
# ```python
#         # fotos (lista com as urls das imagens)
#         image = anuncio.find('img', {'class': 'img-principal'})
#         if image != None:
#             card['fotos'] = image.get('data-imagem-principal')
# ```

# %%
response = urlopen('https://www.euamomomi.com.br/colete-jeans-com-aplicacao-em-moletom-rosa')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')

dados = soup.find('div', {'class': 'container container-product'}) # CONTAINER, contém tudo
imagem = dados.find('div', {'class': 'product-img'})
imagem.find('img', {'itemprop': 'thumbnailUrl'}).get('data-src')
# Out:
# 'https://texcotton.s3-sa-east-1.amazonaws.com/img/2021/06/produto/8239/6/small/f9937-1.jpg'

# %%
tamanhos = dados.find('div', {'id': 'variacao-area-id-2'}).findAll('li')
tamanhos
# Out:
# [<li class="" data-codigo-produto="F9937.JS0001.4" data-derivacao-item-id="14" data-estoque="1" data-proder-id="10094" data-valor="184.90" data-valor-boleto="179.35" data-valor-de="" onclick=""><div class="icon"></div> <div class="variacao-label"> 4 </div></li>,
#  <li class="" data-codigo-produto="F9937.JS0001.6" data-derivacao-item-id="11" data-estoque="1" data-proder-id="10095" data-valor="184.90" data-valor-boleto="179.35" data-valor-de="" onclick=""><div class="icon"></div> <div class="variacao-label"> 6 </div></li>,
#  <li class="" data-codigo-produto="F9937.JS0001.8" data-derivacao-item-id="12" data-estoque="1" data-proder-id="10096" data-valor="184.90" data-valor-boleto="179.35" data-valor-de="" onclick=""><div class="icon"></div> <div class="variacao-label"> 8 </div></li>,
#  <li class="" data-codigo-produto="F9937.JS0001.10" data-derivacao-item-id="17" data-estoque="1" data-proder-id="10090" data-valor="184.90" data-valor-boleto="179.35" data-valor-de="" onclick=""><div class="icon"></div> <div class="variacao-label"> 10 </div></li>,
#  <li class="out-of-stock" data-codigo-produto="F9937.JS0001.12" data-derivacao-item-id="18" data-estoque="0" data-proder-id="10091" data-valor="184.90" data-valor-boleto="179.35" data-valor-de="" onclick=""><div class="icon"></div> <div class="variacao-label"> 12 </div></li>,
#  <li class="" data-codigo-produto="F9937.JS0001.14" data-derivacao-item-id="19" data-estoque="1" data-proder-id="10092" data-valor="184.90" data-valor-boleto="179.35" data-valor-de="" onclick=""><div class="icon"></div> <div class="variacao-label"> 14 </div></li>,
#  <li class="" data-codigo-produto="F9937.JS0001.16" data-derivacao-item-id="20" data-estoque="1" data-proder-id="10093" data-valor="184.90" data-valor-boleto="179.35" data-valor-de="" onclick=""><div class="icon"></div> <div class="variacao-label"> 16 </div></li>]

# %%
tamanho.get("data-estoque")
# Out:
# '1'

# %%
t = []
for tamanho in tamanhos:
    if tamanho.get("data-estoque") != 0:
        num = tamanho.get_text().replace(' ', '')
        t.append(num)

print(t)
# Out:
# ['4', '6', '8', '10', '12', '14', '16']

# %%
card
# Out:
# {'fotos': ['https://texcotton.s3-sa-east-1.amazonaws.com/img/2021/02/produto/4264/camisa-social-infantil-feminina-branca-momi.png',
#   'https://texcotton.s3-sa-east-1.amazonaws.com/img/2021/02/produto/4265/camisa-social-infantil-feminina-branca-momi-gola.png'],
#  'tamanhos': ['4', '6', '8', '10', '12', '14', '16']}
